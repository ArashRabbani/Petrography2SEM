# %% [markdown]
# # Install

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...

# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # Training
#
# -   `!python train.py --dataroot .\pix2pix_dataset\ppl2se --name ppl2se_pix2pix --model pix2pix --direction AtoB --display_id -1 --preprocess scale_width_and_crop --load_size 400 --crop_size 256 --num_threads 0 --output_nc 1 --n_epochs 200 --n_epochs_decay 200`
#
# Change the `--dataroot` and `--name` to your own dataset's path and model's name. Use `--gpu_ids 0,1,..` to train on multiple GPUs and `--batch_size` to change the batch size. Add `--direction BtoA` if you want to train a model to transfrom from class B to A.

# %%
# !python train.py --dataroot .\pix2pix_dataset\ppl2se --name ppl2se_pix2pix --model pix2pix --direction AtoB --display_id -1 --preprocess scale_width_and_crop --load_size 400 --crop_size 256 --num_threads 0 --output_nc 1 --n_epochs 200 --n_epochs_decay 200

# %% [markdown]
# # Testing
#
# -   `python test.py --dataroot .\pix2pix_dataset\xpl2se --direction AtoB --model pix2pix --name xpl2se_pix2pix --preprocess scale_width_and_crop --load_size 400 --crop_size 256 --checkpoints_dir .\checkpoints --results_dir .\pix2pix_results --output_nc 1`
#
# Change the `--dataroot`, `--name`, and `--direction` to be consistent with your trained model's configuration and how you want to transform images.
#
# > from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix:
# > Note that we specified --direction BtoA as Facades dataset's A to B direction is photos to labels.

# %% [markdown]
# Copy the "checkpoints" and "pix2pix_dataset" folder into the "pytorch-CycleGAN-and-pix2pix" folder from zenodo

# %%
# !python test.py --dataroot .\pix2pix_dataset\xpl2se --direction AtoB --model pix2pix --name xpl2se_pix2pix --preprocess scale_width_and_crop --load_size 400 --crop_size 256 --checkpoints_dir .\checkpoints --results_dir .\pix2pix_results --output_nc 1
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: .\checkpoints                 	[default: ./checkpoints]
#                 crop_size: 256
#                  dataroot: .\pix2pix_dataset\xpl2se      	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 400                           	[default: 256]
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
# ...

# %% [markdown]
# # Visualize

# %%
import matplotlib.pyplot as plt

img = plt.imread('.\\pix2pix_results\\xpl2se_pix2pix\\test_latest\\images\\A_0006_fake_B.png')
plt.imshow(img)
